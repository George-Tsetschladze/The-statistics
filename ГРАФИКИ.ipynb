# %%
import pandas   as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
students['math score'].hist()
# Out:
# <AxesSubplot:>

# %%
students.plot.scatter(x='math score', y = 'writing score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='writing score'>

# %%
ax = sns.lmplot(x='math score', y = 'writing score', hue='gender', data = students, fit_reg=False)
ax.set_xlabels('Math')
ax.set_ylabels('Reading')

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
dfe = pd.read_csv('C:\\Users\\fight\\Downloads\\dataset_209770_6.txt', sep =' ')

# %%
dfe
# Out:
#               x            y
# 0    708.960931  1110.042343
# 1    495.791407   307.644315
# 2    500.693063   293.272962
# 3    709.058679  1078.229153
# 4   1393.824629   810.988221
# 5     95.289838   493.790388
# 6    495.755065   303.977877
# 7   1381.924666   806.372152
# 8    712.466068  1089.623932
# 9    687.976508  1094.487931
# 10  1397.809198   786.445425
# 11  1107.049324    98.649469
# 12   391.691888  1298.588591
# 13    97.957783   510.730257
# 14  1091.442898    95.972586
# 15  1403.562037   794.974097
# 16   411.228307  1305.493407
# 17   485.810674   306.690851
# 18  1112.137259   104.293526
# 19  1379.456362   808.104309
# 20   494.498314   301.837401
# 21   509.751711   300.144622
# 22  1415.914132   817.310408
# 23  1098.325488    93.980059
# 24   103.399907   501.831962
# 25  1102.157856   117.117779
# 26   692.875408  1079.963257
# 27  1402.786633   795.989934
# 28   395.458977  1299.787203
# 29  1398.022713   808.463764
# 30  1100.970077    98.078539
# ...

# %%
ax = sns.lmplot(x='x', y = 'y', data = dfe)

# %%
g = pd.read_csv('C:\\Users\\fight\\Downloads\\genome_matrix.csv', index_col=0)

# %%
ax = sns.heatmap(data = g, cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11988/277067775.py in <module>
#       1 ax = sns.heatmap(data = g, cmap="viridis")
# ----> 2 g.xaxis.set_ticks_position('top')
#       3 g.xaxis.set_tick_params(rotation=90)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'xaxis'

# %%
kek = pd.read_csv('C:\\Users\\fight\\Downloads\\dota_hero_stats (1).csv')

# %%
xex = sns.lmport(x = 'roles', y = 'id', data= kek)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11988/3355350184.py in <module>
# ----> 1 xex = sns.lmport(x = 'roles', y = 'id', data= kek)
#
# AttributeError: module 'seaborn' has no attribute 'lmport'

# %%
ax = sns.lmplot(x='roles', y = 'id', data = kek)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11988/3393581567.py in <module>
# ----> 1 ax = sns.lmplot(x='roles', y = 'id', data = kek)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws, size)
# ...

# %%
kek['cnt'] = kek.roles.str.count(',')+1

# %%
kek
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
kek['count_roles'] = kek['roles'].str.split(',').str.len()

# %%
kek['cnt'].hist()
# Out:
# <AxesSubplot:>

# %%
iris = pd.read_csv('C:\\Users\\fight\\Downloads\\iris.csv')

# %%
iris
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0             0           5.1          3.5           1.4          0.2        0
# 1             1           4.9          3.0           1.4          0.2        0
# 2             2           4.7          3.2           1.3          0.2        0
# 3             3           4.6          3.1           1.5          0.2        0
# 4             4           5.0          3.6           1.4          0.2        0
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        2
# 146         146           6.3          2.5           5.0          1.9        2
# 147         147           6.5          3.0           5.2          2.0        2
# 148         148           6.2          3.4           5.4          2.3        2
# 149         149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
sns.kdeplot(data = iris)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
iris_1 = iris.drop(["Unnamed: 0", 'species'], axis=1)

# %%
sns.kdeplot(data = iris_1)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.pairplot(iris_1)
