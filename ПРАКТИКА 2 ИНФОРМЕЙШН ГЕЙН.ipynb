# %%
from sklearn import tree
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
np.random.seed(0)
import math as m
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_score, recall_score

# %%
data_bag = pd.read_csv('C:\\Users\\fight\\Downloads\\train_data_tree.csv')

# %%
data_bag
# Out:
#      sex  exang  num
# 0      1      1    1
# 1      1      1    1
# 2      1      0    1
# 3      1      0    0
# 4      1      0    1
# ..   ...    ...  ...
# 233    1      0    0
# 234    1      1    0
# 235    1      0    1
# 236    1      1    1
# 237    1      0    0
#
# [238 rows x 3 columns]

# %%
X = data_bag.drop('num', axis = 1)
y = data_bag.num

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
plt.figure(figsize=(25, 25))
tree.plot_tree(clf, fontsize=10, feature_names=list(X), filled=True)
# Out:
# [Text(697.5, 1132.5, 'exang <= 0.5\nentropy = 0.996\nsamples = 238\nvalue = [128, 110]'),
#  Text(348.75, 679.5, 'sex <= 0.5\nentropy = 0.903\nsamples = 157\nvalue = [107, 50]'),
#  Text(174.375, 226.5, 'entropy = 0.612\nsamples = 53\nvalue = [45, 8]'),
#  Text(523.125, 226.5, 'entropy = 0.973\nsamples = 104\nvalue = [62, 42]'),
#  Text(1046.25, 679.5, 'sex <= 0.5\nentropy = 0.826\nsamples = 81\nvalue = [21, 60]'),
#  Text(871.875, 226.5, 'entropy = 0.954\nsamples = 16\nvalue = [6, 10]'),
#  Text(1220.625, 226.5, 'entropy = 0.779\nsamples = 65\nvalue = [15, 50]')]

# %%
Information_gain = 0.996 - ((157/238)*0.903 + (81/238)*0.826)

# %%
Information_gain
# Out:
# 0.11920588235294116
