# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas   as pd
import numpy as np
matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
#   File "C:\Users\fight\AppData\Local\Temp/ipykernel_7684/1076825702.py", line 3
#     matplotlib inline
#                ^
# SyntaxError: invalid syntax

# %%
students.loc[students.lunch == 'standard', ['test_preparation_course', 'gender' ]]
# Out:
#     test_preparation_course  gender
# 0                      none  female
# 1                 completed  female
# 2                      none  female
# 4                      none    male
# 5                      none  female
# ..                      ...     ...
# 987               completed    male
# 991               completed  female
# 994                    none    male
# 995               completed  female
# 998               completed  female
#
# [645 rows x 2 columns]

# %%
students.iloc[[1, 4, 5, 6], 0:8]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 1  female        group C                some college  standard
# 4    male        group C                some college  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 1               completed          69             90             88
# 4                    none          76             78             75
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
students = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
 t = students.iloc[[1, 2]]

# %%
t.index = ['kek', 'puk']

# %%
t
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# kek  female        group C                some college  standard
# puk  female        group B             master's degree  standard
#
#     test preparation course  math score  reading score  writing score
# kek               completed          69             90             88
# puk                    none          90             95             93

# %%
t.loc[['kek']]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# kek  female        group C                some college  standard
#
#     test preparation course  math score  reading score  writing score
# kek               completed          69             90             88

# %%
t.loc[['kek', 'puk'], ['test preparation course', 'gender']]
# Out:
#     test preparation course  gender
# kek               completed  female
# puk                    none  female

# %%
t.iloc[:, 0]
# Out:
# kek    female
# puk    female
# Name: gender, dtype: object

# %%
y = pd.Series([1, 2], index=['kek', 'puk'])

# %%
u = pd.Series([3, 4], index=['kek', 'puk'])

# %%
r = pd.DataFrame({'1':y, '2':u})

# %%
r
# Out:
#      1  2
# kek  1  3
# puk  2  4

# %%
t[['gender']]
# Out:
#      gender
# kek  female
# puk  female

# %%
students.head(7)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
students.iloc[:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
students.loc[:6]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
students.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
titanic = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')

# %%
titanic.size
# Out:
# 10692

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
titanic.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# dtype: int64

# %%
students[students.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
 o = students['writing score'].mean()

# %%
students[students['writing score'] > 0]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance[students_performance['writing score'] > 100 & students_performance.gender == 'female']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23172/154177594.py in <module>
# ----> 1 students_performance[students_performance['writing score'] > 100 & students_performance.gender == 'female']
#
# NameError: name 'students_performance' is not defined

# %%
students[students['lunch'] == 'free/reduced']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students[students['lunch'] == 'free/reduced'].mean()
# Out:
# C:\Users\fight\AppData\Local\Temp/ipykernel_23172/4290447366.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   students[students['lunch'] == 'free/reduced'].mean()
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
students[students['lunch'] == 'standard'].mean()
# Out:
# C:\Users\fight\AppData\Local\Temp/ipykernel_23172/1430017890.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   students[students['lunch'] == 'standard'].mean()
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
students[students['lunch'] == 'standard'].var()
# Out:
# C:\Users\fight\AppData\Local\Temp/ipykernel_23172/3625956906.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   students[students['lunch'] == 'standard'].var()
# math score       186.418089
# reading score    191.285560
# writing score    205.620887
# dtype: float64

# %%
students[students['lunch'] == 'free/reduced'].var()
# Out:
# C:\Users\fight\AppData\Local\Temp/ipykernel_23172/319072259.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   students[students['lunch'] == 'free/reduced'].var()
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
students = students\
                                    .rename(columns=
                                            {'parental level of education': 'parental_level_of_education',
                                            'test preparation course': 'test_preparation_course',
                                            'math score': 'math_score',
                                            'reading score': 'reading_score',
                                            'writing score': 'writing_score'})

# %%
students
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students.query('math_score > 74 & lunch == "standard"')
# Out:
#      gender race/ethnicity parental_level_of_education     lunch  \
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 6    female        group B                some college  standard
# 13     male        group A                some college  standard
# 16     male        group C                 high school  standard
# ..      ...            ...                         ...       ...
# 981    male        group D            some high school  standard
# 982    male        group B            some high school  standard
# 983  female        group A                some college  standard
# 987    male        group E            some high school  standard
# 995  female        group E             master's degree  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 2                      none          90             95             93
# ...

# %%
[i for i in list(students) if 'score' in i]
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
students.filter(like='score', axis=0)
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental_level_of_education, lunch, test_preparation_course, math_score, reading_score, writing_score]
# Index: []

# %%
students.groupby('gender').mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
students.groupby('gender').aggregate({'math score' : 'mean', 'reading score': 'mean'})
# Out:
#         math score  reading score
# gender
# female   63.633205      72.608108
# male     68.728216      65.473029

# %%
students.groupby('gender', as_index=False).\
    aggregate({'math_score' : 'mean', 'reading_score': 'mean'})\
    .rename(columns={'math score' : 'mean_math', 'reading score' : 'mean_reading'})
# Out:
#    gender  math_score  reading_score
# 0  female   63.633205      72.608108
# 1    male   68.728216      65.473029

# %%
students.groupby('gender', as_index=False).\
    aggregate(mean_math_score= ('math_score','mean'), mean_reading_score= ('reading_score','mean'))
# Out:
#    gender  mean_math_score  mean_reading_score
# 0  female        63.633205           72.608108
# 1    male        68.728216           65.473029

# %%
students.groupby(['gender', 'race/ethnicity'],  as_index=False).\
    aggregate(mean_math_score= ('math_score','mean'), mean_reading_score= ('reading_score','mean'))
# Out:
#    gender race/ethnicity  mean_math_score  mean_reading_score
# 0  female        group A        58.527778           69.000000
# 1  female        group B        61.403846           71.076923
# 2  female        group C        62.033333           71.944444
# 3  female        group D        65.248062           74.046512
# 4  female        group E        70.811594           75.840580
# 5    male        group A        63.735849           61.735849
# 6    male        group B        65.930233           62.848837
# 7    male        group C        67.611511           65.424460
# 8    male        group D        69.413534           66.135338
# 9    male        group E        76.746479           70.295775

# %%
 vse_means = students.groupby(['gender', 'race/ethnicity']).\
    aggregate(mean_math_score= ('math_score','mean'), mean_reading_score= ('reading_score','mean'))

# %%
vse_means.index
# Out:
# MultiIndex([('female', 'group A'),
#             ('female', 'group B'),
#             ('female', 'group C'),
#             ('female', 'group D'),
#             ('female', 'group E'),
#             (  'male', 'group A'),
#             (  'male', 'group B'),
#             (  'male', 'group C'),
#             (  'male', 'group D'),
#             (  'male', 'group E')],
#            names=['gender', 'race/ethnicity'])

# %%
vse_means.loc[[('female', 'group A'), ('female', 'group B')]]
# Out:
#                        mean_math_score  mean_reading_score
# gender race/ethnicity
# female group A               58.527778           69.000000
#        group B               61.403846           71.076923

# %%
students.groupby(['gender', 'race/ethnicity']).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %%
students.sort_values(['gender', 'race/ethnicity'])
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 14   female        group A             master's degree      standard
# 46   female        group A          associate's degree      standard
# 72   female        group A          associate's degree  free/reduced
# 88   female        group A                some college      standard
# 129  female        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 928    male        group E          associate's degree  free/reduced
# 950    male        group E                 high school      standard
# 955    male        group E          associate's degree      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students.sort_values(['gender', 'math_score'], ascending=False)\
    .groupby('gender').head(5)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
students['total_score'] = students.math_score+students.reading_score+students.writing_score

# %%
students
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
students = students.assign(total_score_log = np.log(students.total_score))

# %%
students
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
students.drop(['total_score'], axis=1)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
students
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
dota2 = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
dota2
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
dota2.query('legs == 8').value_counts()
# Out:
# Unnamed: 0  attack_type  id  legs  localized_name  name                       primary_attr  roles
# 59          Melee        61  8     Broodmother     npc_dota_hero_broodmother  agi           ['Carry', 'Pusher', 'Escape', 'Nuker']    1
# dtype: int64

# %%
pup = pd.read_csv('C:\\Users\\fight\Downloads\\accountancy.csv', sep = ',', encoding='windows-1251')

# %%
pup.groupby(['Type', 'Executor'])\
    .aggregate(mean_salary= ('Salary', 'mean'))
# Out:
#                mean_salary
# Type Executor
# A    Loopa       58.000000
#      Pupa       160.833333
# B    Loopa      145.166667
#      Pupa        77.000000
# C    Loopa      154.333333
#      Pupa        74.500000
# D    Loopa      137.714286
#      Pupa       146.500000
# E    Loopa      164.000000
#      Pupa       131.200000
# F    Loopa      238.000000
#      Pupa       136.250000

# %%
dota2.sort_values(['attack_type', 'primary_attr']).\
    groupby('attack_type').head(116)
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 3             3       Melee    4     2     Bloodseeker
# 7             7       Melee    8     2      Juggernaut
# 11           11       Melee   12     2  Phantom Lancer
# 30           30       Melee   32     2            Riki
# ..          ...         ...  ...   ...             ...
# 113         113      Ranged  119     2     Dark Willow
# 115         115      Ranged  121     2      Grimstroke
# 57           57      Ranged   59     2          Huskar
# 89           89      Ranged   91     0              Io
# 108         108      Ranged  110     2         Phoenix
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 3       npc_dota_hero_bloodseeker          agi
# 7        npc_dota_hero_juggernaut          agi
# 11   npc_dota_hero_phantom_lancer          agi
# 30             npc_dota_hero_riki          agi
# ...

# %%
dota2.sort_values(['attack_type', 'primary_attr']).describe()
# Out:
#        Unnamed: 0          id        legs
# count  117.000000  117.000000  117.000000
# mean    58.000000   60.000000    2.085470
# std     33.919021   34.545323    1.156486
# min      0.000000    1.000000    0.000000
# 25%     29.000000   31.000000    2.000000
# 50%     58.000000   60.000000    2.000000
# 75%     87.000000   89.000000    2.000000
# max    116.000000  129.000000    8.000000

# %%
dota2.groupby(['attack_type', 'primary_attr']).describe()
# Out:
#                          Unnamed: 0                                           \
#                               count       mean        std   min    25%   50%
# attack_type primary_attr
# Melee       agi                19.0  61.315789  38.233279   0.0  34.50  65.0
#             int                 2.0  67.500000  20.506097  53.0  60.25  67.5
#             str                35.0  62.657143  34.265351   1.0  31.50  69.0
# Ranged      agi                18.0  46.111111  32.737618   5.0  15.25  44.5
#             int                40.0  55.225000  32.472069   2.0  28.75  50.5
#             str                 3.0  84.666667  25.774665  57.0  73.00  89.0
#
#                                           id             ...                 \
#                             75%    max count       mean  ...     75%    max
# attack_type primary_attr                                 ...
# Melee       agi           89.00  114.0  19.0  63.315789  ...   91.00  120.0
# ...

# %%
concentrations = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
concentrations = concentrations.assign(mean_concentration = concentrations.sucrose + concentrations.alanin + concentrations.citrate + concentrations.alanin + concentrations.glucose + concentrations.oleic_acid)

# %%
mean_concentrations =concentrations.groupby(['genus'])\
    .aggregate(
    mean_suc = ('sucrose', 'mean'),
    mean_alanin = ('alanin', 'mean'),
    mean_citrate = ('citrate', 'mean'),
    mean_glucose = ('glucose', 'mean'),
    mean_oleic_acid = ('oleic_acid', 'mean')
)

# %%
mean_concentrations
# Out:
#              mean_suc  mean_alanin  mean_citrate  mean_glucose  \
# genus
# Ascophyllum  6.825467     0.875429      5.253527      3.414961
# Cladophora   4.008792     3.997055      5.288311      2.800276
# Fucus        4.355112     3.566411      4.214878      2.814803
# Palmaria     0.704580     3.176440      5.573905      3.242090
# Saccharina   4.183596     3.524207      3.346710      4.980594
#
#              mean_oleic_acid
# genus
# Ascophyllum         2.432526
# Cladophora          2.263472
# Fucus               3.367647
# Palmaria            2.245538
# Saccharina          4.487252

# %%
concentrations.groupby(['genus','alanin']).describe()
# Out:
#                      sucrose                                              \
#                        count      mean std       min       25%       50%
# genus       alanin
# Ascophyllum 0.875429     1.0  6.825467 NaN  6.825467  6.825467  6.825467
# Cladophora  1.648450     1.0  3.861470 NaN  3.861470  3.861470  3.861470
#             3.461692     1.0  5.712284 NaN  5.712284  5.712284  5.712284
#             6.881024     1.0  2.452623 NaN  2.452623  2.452623  2.452623
# Fucus       0.346431     1.0  3.276870 NaN  3.276870  3.276870  3.276870
#             3.711498     1.0  3.001472 NaN  3.001472  3.001472  3.001472
#             6.641303     1.0  6.786996 NaN  6.786996  6.786996  6.786996
# Palmaria    3.176440     1.0  0.704580 NaN  0.704580  0.704580  0.704580
# Saccharina  1.255251     1.0  6.731070 NaN  6.731070  6.731070  6.731070
#             5.793163     1.0  1.636122 NaN  1.636122  1.636122  1.636122
#
# ...

# %%
concentrations.groupby(['genus','alanin'])

# %%
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid  mean_concentration
# 0  2.548459    6.405165           24.382353
# 1  6.013219    4.156700           25.032991
# ...

# %%
mean_concentrationsqqq =concentrations.groupby(['genus', 'alanin'])

# %%
students.math_score
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
